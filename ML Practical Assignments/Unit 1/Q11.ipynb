# %%
#Write a Machine Learning program to Given a CSV file named 1.csv, 
#perform the following tasks: 
#1. Load the CSV file into a Pandas DataFrame and print its 
#contents. 
#2. Check and print the maximum number of rows that Pandas will 
#display by default. 
#3. Display the first 5 rows of the DataFrame. 
#4. Display the last 5 rows of the DataFrame.

# %%
import pandas as pd

# %%
#1. Load the CSV file into a Pandas DataFrame and print its 
#contents. 
df=pd.read_csv('1.csv')

print("Full DataFrame:")
print(df)
# Out:
# Full DataFrame:
#      Name  Location  Age
# 0    John  New York   24
# 1    Anna     Paris   13
# 2   Peter    Berlin   53
# 3   Linda    London   33
# 4    Mark     Tokyo   41
# 5  Sophie    Sydney   29
# 6   David   Toronto   37

# %%
#2. Check and print the maximum number of rows that Pandas will 
#display by default. 
print("Max Rows displayed by pandas:")
print(pd.get_option('display.max_rows'))
# Out:
# Max Rows displayed by pandas:
# 60

# %%
#3. Display the first 5 rows of the DataFrame. 
print("First 5 rows:")
print(df.head())
# Out:
# First 5 rows:
#     Name  Location  Age
# 0   John  New York   24
# 1   Anna     Paris   13
# 2  Peter    Berlin   53
# 3  Linda    London   33
# 4   Mark     Tokyo   41

# %%
#4. Display the last 5 rows of the DataFrame. 
print("Last 5 rows:")
print(df.tail())
# Out:
# Last 5 rows:
#      Name Location  Age
# 2   Peter   Berlin   53
# 3   Linda   London   33
# 4    Mark    Tokyo   41
# 5  Sophie   Sydney   29
# 6   David  Toronto   37
